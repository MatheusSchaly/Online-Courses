# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('linear_reg').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Importing the dataset
df = spark.read.csv('/FileStore/tables/cruise_ship_info.csv', inferSchema=True, header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------+---+------------------+----------+------+------+-----------------+----+
#   Ship_name|Cruise_line|Age|           Tonnage|passengers|length|cabins|passenger_density|crew|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+
#     Journey|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|
#       Quest|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|
# Celebration|   Carnival| 26|            47.262|     14.86|  7.22|  7.43|             31.8| 6.7|
#    Conquest|   Carnival| 11|             110.0|     29.74|  9.53| 14.88|            36.99|19.1|
#     Destiny|   Carnival| 17|           101.353|     26.42|  8.92| 13.21|            38.36|10.0|
#     Ecstasy|   Carnival| 22|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|
#     Elation|   Carnival| 15|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|
#     Fantasy|   Carnival| 23|            70.367|     20.56|  8.55| 10.22|            34.23| 9.2|
# Fascination|   Carnival| 19|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|
#     Freedom|   Carnival|  6|110.23899999999999|      37.0|  9.51| 14.87|            29.79|11.5|
#       Glory|   Carnival| 10|             110.0|     29.74|  9.51| 14.87|            36.99|11.6|
#     Holiday|   Carnival| 28|            46.052|     14.52|  7.27|  7.26|            31.72| 6.6|
# Imagination|   Carnival| 18|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|
# Inspiration|   Carnival| 17|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|
#      Legend|   Carnival| 11|              86.0|     21.24|  9.63| 10.62|            40.49| 9.3|
#    Liberty*|   Carnival|  8|             110.0|     29.74|  9.51| 14.87|            36.99|11.6|
#     Miracle|   Carnival|  9|              88.5|     21.24|  9.63| 10.62|            41.67|10.3|
#    Paradise|   Carnival| 15|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|
#       Pride|   Carnival| 12|              88.5|     21.24|  9.63| 11.62|            41.67| 9.3|
#   Sensation|   Carnival| 20|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+
# only showing top 20 rows
#
# </div>

# %%
# StringIndexer for the categorical column
from pyspark.ml.feature import StringIndexer
indexer = StringIndexer(inputCol='Cruise_line', outputCol='Cruise_line_cat')
df = indexer.fit(df).transform(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------+---+------------------+----------+------+------+-----------------+----+---------------+
#   Ship_name|Cruise_line|Age|           Tonnage|passengers|length|cabins|passenger_density|crew|Cruise_line_cat|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+---------------+
#     Journey|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|           16.0|
#       Quest|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|           16.0|
# Celebration|   Carnival| 26|            47.262|     14.86|  7.22|  7.43|             31.8| 6.7|            1.0|
#    Conquest|   Carnival| 11|             110.0|     29.74|  9.53| 14.88|            36.99|19.1|            1.0|
#     Destiny|   Carnival| 17|           101.353|     26.42|  8.92| 13.21|            38.36|10.0|            1.0|
#     Ecstasy|   Carnival| 22|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|            1.0|
#     Elation|   Carnival| 15|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|            1.0|
#     Fantasy|   Carnival| 23|            70.367|     20.56|  8.55| 10.22|            34.23| 9.2|            1.0|
# Fascination|   Carnival| 19|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|            1.0|
#     Freedom|   Carnival|  6|110.23899999999999|      37.0|  9.51| 14.87|            29.79|11.5|            1.0|
#       Glory|   Carnival| 10|             110.0|     29.74|  9.51| 14.87|            36.99|11.6|            1.0|
#     Holiday|   Carnival| 28|            46.052|     14.52|  7.27|  7.26|            31.72| 6.6|            1.0|
# Imagination|   Carnival| 18|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|            1.0|
# Inspiration|   Carnival| 17|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|            1.0|
#      Legend|   Carnival| 11|              86.0|     21.24|  9.63| 10.62|            40.49| 9.3|            1.0|
#    Liberty*|   Carnival|  8|             110.0|     29.74|  9.51| 14.87|            36.99|11.6|            1.0|
#     Miracle|   Carnival|  9|              88.5|     21.24|  9.63| 10.62|            41.67|10.3|            1.0|
#    Paradise|   Carnival| 15|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|            1.0|
#       Pride|   Carnival| 12|              88.5|     21.24|  9.63| 11.62|            41.67| 9.3|            1.0|
#   Sensation|   Carnival| 20|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|            1.0|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+---------------+
# only showing top 20 rows
#
# </div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: [&#39;Ship_name&#39;,
#  &#39;Cruise_line&#39;,
#  &#39;Age&#39;,
#  &#39;Tonnage&#39;,
#  &#39;passengers&#39;,
#  &#39;length&#39;,
#  &#39;cabins&#39;,
#  &#39;passenger_density&#39;,
#  &#39;crew&#39;,
#  &#39;Cruise_line_cat&#39;]</div>

# %%
df.columns[2:8] + df.columns[-1:]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: [&#39;Age&#39;,
#  &#39;Tonnage&#39;,
#  &#39;passengers&#39;,
#  &#39;length&#39;,
#  &#39;cabins&#39;,
#  &#39;passenger_density&#39;,
#  &#39;Cruise_line_cat&#39;]</div>

# %%
# Transforming the dataframe into a dataframe accepted by PySpark ml algorithms
from pyspark.ml.feature import VectorAssembler
vectorAssembler = VectorAssembler(inputCols=df.columns[2:8] + df.columns[-1:], outputCol='features')
df_final = vectorAssembler.transform(df).select('features', 'crew')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_final.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----+
#             features|crew|
# +--------------------+----+
# [6.0,30.276999999...|3.55|
# [6.0,30.276999999...|3.55|
# [26.0,47.262,14.8...| 6.7|
# [11.0,110.0,29.74...|19.1|
# [17.0,101.353,26....|10.0|
# [22.0,70.367,20.5...| 9.2|
# [15.0,70.367,20.5...| 9.2|
# [23.0,70.367,20.5...| 9.2|
# [19.0,70.367,20.5...| 9.2|
# [6.0,110.23899999...|11.5|
# [10.0,110.0,29.74...|11.6|
# [28.0,46.052,14.5...| 6.6|
# [18.0,70.367,20.5...| 9.2|
# [17.0,70.367,20.5...| 9.2|
# [11.0,86.0,21.24,...| 9.3|
# [8.0,110.0,29.74,...|11.6|
# [9.0,88.5,21.24,9...|10.3|
# [15.0,70.367,20.5...| 9.2|
# [12.0,88.5,21.24,...| 9.3|
# [20.0,70.367,20.5...| 9.2|
# +--------------------+----+
# only showing top 20 rows
#
# </div>

# %%
# Train test split
train_data, test_data = df_final.randomSplit([0.7, 0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+
# summary|              crew|
# +-------+------------------+
#   count|               113|
#    mean| 8.099557522123902|
#  stddev|3.4427414298005647|
#     min|              0.88|
#     max|              21.0|
# +-------+------------------+
#
# </div>

# %%
test_data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+
# summary|              crew|
# +-------+------------------+
#   count|                45|
#    mean| 7.027333333333332|
#  stddev|3.5758243804750807|
#     min|              0.59|
#     max|              13.6|
# +-------+------------------+
#
# </div>

# %%
# Fitting the model
from pyspark.ml.regression import LinearRegression
regressor = LinearRegression(featuresCol='features', labelCol='crew', predictionCol='predictions')
regressor = regressor.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Doing some predictions
test_results = regressor.evaluate(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_results.rootMeanSquaredError
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: 0.5666450962877022</div>

# %%
test_results.r2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: 0.9743179466066777</div>

# %%
df.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+---------+-----------+------------------+------------------+-----------------+-----------------+------------------+-----------------+-----------------+-----------------+
# summary|Ship_name|Cruise_line|               Age|           Tonnage|       passengers|           length|            cabins|passenger_density|             crew|  Cruise_line_cat|
# +-------+---------+-----------+------------------+------------------+-----------------+-----------------+------------------+-----------------+-----------------+-----------------+
#   count|      158|        158|               158|               158|              158|              158|               158|              158|              158|              158|
#    mean| Infinity|       null|15.689873417721518| 71.28467088607599|18.45740506329114|8.130632911392404| 8.830000000000005|39.90094936708861|7.794177215189873|5.063291139240507|
#  stddev|      NaN|       null| 7.615691058751413|37.229540025907866|9.677094775143416|1.793473548054825|4.4714172221480615| 8.63921711391542|3.503486564627034|4.758744608182735|
#     min|Adventure|    Azamara|                 4|             2.329|             0.66|             2.79|              0.33|             17.7|             0.59|              0.0|
#     max|Zuiderdam|   Windstar|                48|             220.0|             54.0|            11.82|              27.0|            71.43|             21.0|             19.0|
# +-------+---------+-----------+------------------+------------------+-----------------+-----------------+------------------+-----------------+-----------------+-----------------+
#
# </div>

# %%
from pyspark.sql.functions import corr
df.select(corr('crew', 'passengers')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------------+
# corr(crew, passengers)|
# +----------------------+
#     0.9152341306065384|
# +----------------------+
#
# </div>

# %%
df.select(corr('crew', 'cabins')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
# corr(crew, cabins)|
# +------------------+
# 0.9508226063578497|
# +------------------+
#
# </div>

# %%
df.select(corr('crew', 'Tonnage')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+
# corr(crew, Tonnage)|
# +-------------------+
#   0.927568811544939|
# +-------------------+
#
# </div>

# %%
df.select(corr('crew', 'Age')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+
#     corr(crew, Age)|
# +-------------------+
# -0.5306565039638852|
# +-------------------+
#
# </div>

# %%
# Predicting on unlabeled test set
unlabeled_data = test_data.select('features')
predictions = regressor.transform(unlabeled_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions.select('predictions').head(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[54]: [Row(predictions=11.855697167086266),
#  Row(predictions=10.151472377128044),
#  Row(predictions=11.116521075351358),
#  Row(predictions=13.90591669998405),
#  Row(predictions=11.327646545683383),
#  Row(predictions=8.79747935002662),
#  Row(predictions=11.224714092278408),
#  Row(predictions=9.214541892187299),
#  Row(predictions=11.077205939294014),
#  Row(predictions=0.42632033716369566)]</div>

# %%
test_data.select('crew').head(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: [Row(crew=12.2),
#  Row(crew=9.0),
#  Row(crew=11.5),
#  Row(crew=13.6),
#  Row(crew=12.38),
#  Row(crew=9.0),
#  Row(crew=10.68),
#  Row(crew=9.99),
#  Row(crew=12.0),
#  Row(crew=0.6)]</div>
