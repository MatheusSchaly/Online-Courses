# %%
# Initialising a SparkSession
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('dt_rf_gbt').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Loading the dataset
df = spark.sql('SELECT * FROM dog_food_csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+----+---+-------+
#   A|  B|   C|  D|Spoiled|
# +---+---+----+---+-------+
#   4|  2|12.0|  3|    1.0|
#   5|  6|12.0|  7|    1.0|
#   6|  2|13.0|  6|    1.0|
#   4|  2|12.0|  1|    1.0|
#   4|  2|12.0|  3|    1.0|
#  10|  3|13.0|  9|    1.0|
#   8|  5|14.0|  5|    1.0|
#   5|  8|12.0|  8|    1.0|
#   6|  5|12.0|  9|    1.0|
#   3|  3|12.0|  1|    1.0|
#   9|  8|11.0|  3|    1.0|
#   1| 10|12.0|  3|    1.0|
#   1|  5|13.0| 10|    1.0|
#   2| 10|12.0|  6|    1.0|
#   1| 10|11.0|  4|    1.0|
#   5|  3|12.0|  2|    1.0|
#   4|  9|11.0|  8|    1.0|
#   5|  1|11.0|  1|    1.0|
#   4|  9|12.0| 10|    1.0|
#   5|  8|10.0|  9|    1.0|
# +---+---+----+---+-------+
# only showing top 20 rows
#
# </div>

# %%
# Converting the dataset to features and label
from pyspark.ml.feature import VectorAssembler
assembler = VectorAssembler(inputCols = df.columns[:-1],
                           outputCol = 'features')
final_df = assembler.transform(df).select('features', 'Spoiled')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Instantiating the models
from pyspark.ml.classification import DecisionTreeClassifier, RandomForestClassifier, GBTClassifier
dtc = DecisionTreeClassifier(labelCol = 'Spoiled')
rfc = RandomForestClassifier(labelCol = 'Spoiled', numTrees = 250)
gbtc = GBTClassifier(labelCol = 'Spoiled')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Fitting the models
dtc_model = dtc.fit(final_df)
rfc_model = rfc.fit(final_df)
gbtc_model = gbtc.fit(final_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Selecting the best features
print('DTC:', end='')
dtc_model.featureImportances
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DTC:Out[21]: SparseVector(4, {1: 0.0019, 2: 0.9832, 3: 0.0149})</div>

# %%
print('RFC:', end='')
rfc_model.featureImportances
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RFC:Out[24]: SparseVector(4, {0: 0.0173, 1: 0.0191, 2: 0.9435, 3: 0.0201})</div>

# %%
print('GBTC:', end='')
gbtc_model.featureImportances
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">GBTC:Out[23]: SparseVector(4, {0: 0.0434, 1: 0.0539, 2: 0.7923, 3: 0.1104})</div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+----+---+-------+
#   A|  B|   C|  D|Spoiled|
# +---+---+----+---+-------+
#   4|  2|12.0|  3|    1.0|
#   5|  6|12.0|  7|    1.0|
#   6|  2|13.0|  6|    1.0|
#   4|  2|12.0|  1|    1.0|
#   4|  2|12.0|  3|    1.0|
#  10|  3|13.0|  9|    1.0|
#   8|  5|14.0|  5|    1.0|
#   5|  8|12.0|  8|    1.0|
#   6|  5|12.0|  9|    1.0|
#   3|  3|12.0|  1|    1.0|
#   9|  8|11.0|  3|    1.0|
#   1| 10|12.0|  3|    1.0|
#   1|  5|13.0| 10|    1.0|
#   2| 10|12.0|  6|    1.0|
#   1| 10|11.0|  4|    1.0|
#   5|  3|12.0|  2|    1.0|
#   4|  9|11.0|  8|    1.0|
#   5|  1|11.0|  1|    1.0|
#   4|  9|12.0| 10|    1.0|
#   5|  8|10.0|  9|    1.0|
# +---+---+----+---+-------+
# only showing top 20 rows
#
# </div>
