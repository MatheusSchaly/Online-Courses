# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the dataset

# %%
df = pd.read_csv('Market_Basket_Optimisation.csv', header=None)

# %% [markdown]
# ### Visualising items' frequencies

# %%
df.stack().value_counts(normalize=True)[:10].plot(kind='bar', title='Relative Frequency')

# %%
df.stack().value_counts().apply(lambda item: item / df.shape[0])[:10].plot(kind='bar', title='Frequency') # Frequency

# %% [markdown]
# ### Formatting the dataset

# %%
transactions = []
for i in range(df.shape[0]):
    row = df.iloc[i].dropna().tolist()
    transactions.append(row)

# %% [markdown]
# ### Building the model

# %%
# !pip install apyori
from apyori import apriori
rules = apriori(transactions=transactions, 
                min_support=0.004, # how frequent is your item(s) in the dataset
                min_length=2, 
                max_length=0)
results = list(rules)

# %% [markdown]
# ### Organizing the model's output

# %%
def inspect(results):
    item_sets = []
    supports = [] 
    for result in results:
        item_sets.append(tuple(result[0]))
        supports.append(result[1])
    return list(zip(item_sets, supports))
results_df = pd.DataFrame(inspect(results),
                          columns = ['Item Set', 'Support'])

# %%
pd.set_option('display.max_rows', df.shape[0])
results_df.sort_values('Support', ascending=False)[:100]
# Out:
#                                Item Set   Support
# 69                     (mineral water,)  0.238368
# 34                              (eggs,)  0.179709
# 96                         (spaghetti,)  0.174110
# 40                      (french fries,)  0.170911
# 23                         (chocolate,)  0.163845
# 51                         (green tea,)  0.132116
# 68                              (milk,)  0.129583
# 52                       (ground beef,)  0.098254
# 46                 (frozen vegetables,)  0.095321
# 78                          (pancakes,)  0.095054
# 13                           (burgers,)  0.087188
# 15                              (cake,)  0.081056
# 28                           (cookies,)  0.080389
# 37                          (escalope,)  0.079323
# 62                    (low fat yogurt,)  0.076523
# 93                            (shrimp,)  0.071457
# 103                         (tomatoes,)  0.068391
# 77                         (olive oil,)  0.065858
# 45                   (frozen smoothie,)  0.063325
# 105                           (turkey,)  0.062525
# 21                           (chicken,)  0.059992
# 631          (spaghetti, mineral water)  0.059725
# 110                 (whole wheat rice,)  0.058526
# 282          (mineral water, chocolate)  0.052660
# 48                     (grated cheese,)  0.052393
# 29                       (cooking oil,)  0.051060
# 362               (mineral water, eggs)  0.050927
# 95                              (soup,)  0.050527
# 56                     (herb & pepper,)  0.049460
# 602               (mineral water, milk)  0.047994
# 57                             (honey,)  0.047460
# 20                         (champagne,)  0.046794
# 42                       (fresh bread,)  0.043061
# 88                            (salmon,)  0.042528
# 543        (mineral water, ground beef)  0.040928
# 294              (spaghetti, chocolate)  0.039195
# 552            (spaghetti, ground beef)  0.039195
# 371                   (spaghetti, eggs)  0.036528
# 346                (french fries, eggs)  0.036395
# 485  (frozen vegetables, mineral water)  0.035729
# 610                   (spaghetti, milk)  0.035462
# 266           (french fries, chocolate)  0.034395
# 419       (mineral water, french fries)  0.033729
# 622           (pancakes, mineral water)  0.033729
# 10                          (brownies,)  0.033729
# 3                            (avocado,)  0.033329
# 264                   (chocolate, eggs)  0.033196
# 58                          (hot dogs,)  0.032396
# 281                   (milk, chocolate)  0.032129
# 31                    (cottage cheese,)  0.031862
# 522          (mineral water, green tea)  0.031063
# 361                        (milk, eggs)  0.030796
# 101                     (tomato juice,)  0.030396
# 14                            (butter,)  0.030129
# 109                (whole wheat pasta,)  0.029463
# 157                     (burgers, eggs)  0.028796
# 410           (french fries, green tea)  0.028530
# 85                          (red wine,)  0.028130
# 492      (frozen vegetables, spaghetti)  0.027863
# 621          (mineral water, olive oil)  0.027596
# 429           (spaghetti, french fries)  0.027596
# 207               (mineral water, cake)  0.027463
# 112                      (yogurt cake,)  0.027330
# 61                        (light mayo,)  0.027196
# 35                        (energy bar,)  0.027063
# 36                      (energy drink,)  0.026663
# 81                            (pepper,)  0.026530
# 531              (spaghetti, green tea)  0.026530
# 54                               (ham,)  0.026530
# 19                           (cereals,)  0.025730
# 106                   (vegetables mix,)  0.025730
# 353                   (green tea, eggs)  0.025463
# 656               (pancakes, spaghetti)  0.025197
# 171            (burgers, mineral water)  0.024397
# 635           (mineral water, tomatoes)  0.024397
# 72                           (muffins,)  0.024130
# 590     (mineral water, low fat yogurt)  0.023997
# 418                (french fries, milk)  0.023730
# 629             (mineral water, shrimp)  0.023597
# 484           (frozen vegetables, milk)  0.023597
# 273              (green tea, chocolate)  0.023464
# 274            (ground beef, chocolate)  0.023064
# 76                               (oil,)  0.023064
# 630               (soup, mineral water)  0.023064
# 648              (spaghetti, olive oil)  0.022930
# 271      (frozen vegetables, chocolate)  0.022930
# 252            (mineral water, chicken)  0.022797
# 41                       (french wine,)  0.022530
# 43                        (fresh tuna,)  0.022264
# 159             (burgers, french fries)  0.021997
# 542                 (ground beef, milk)  0.021997
# 364                    (pancakes, eggs)  0.021730
# 351           (frozen vegetables, eggs)  0.021730
# 177                (burgers, spaghetti)  0.021464
# 99                      (strawberries,)  0.021330
# 673                 (spaghetti, shrimp)  0.021197
# 66                         (meatballs,)  0.020931
# 683               (spaghetti, tomatoes)  0.020931
# 0                            (almonds,)  0.020397
# 468    (frozen smoothie, mineral water)  0.020264
